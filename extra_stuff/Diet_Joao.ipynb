# %% [markdown]
# # Finding the right ingredients to provide

# %% [markdown]
# The following dataframe we obtained has nutritional information about the most varied food products there are. The information we are most interested in for our analysis. per product, are:
# * **Food Group** - a generalized group in which the product is inserted
# * **Food Name** - the name of the product itself
# * **Protein (g)** - The amount of grams of proteins in a 100g serving
# * **Carbohydrates (g)** - The amount of grams of carbohydrates in a 100g serving
# * **Fat (g)** - The amount of grams of fat in a 100g serving

# %% [markdown]
# From the national agriculture library (https://www.nal.usda.gov/fnic/how-many-calories-are-one-gram-fat-carbohydrate-or-protein), we know that 1 gram of protein, fat and carbohydrates proved 4, 9 and 4 Kcal each, respectively.
#
# As such, and taking into account the necessity that each person, in their diet, should have their calories coming (**REFERENCE**):
# * 55% from proteins
# * 25% from carbohydrates
# * 20% from fats.
#
# In order to decide which products we want to provide to our needed countries, we'll apply a greedy rank that tries to find products which most closely respect these percentages.

# %%
import pandas as pd
test = pd.read_csv("../test_rank.csv").drop(columns="Unnamed: 0")
test
# Out:
#                        Food Group                                  Food Name  \
# 0     Legumes and Legume Products                    Soy meal, defatted, raw
# 1     Legumes and Legume Products                   Soy flour, full-fat, raw
# 2     Legumes and Legume Products                Soybeans, mature seeds, raw
# 3     Legumes and Legume Products                  Lupins, mature seeds, raw
# 4     Legumes and Legume Products            Winged beans, mature seeds, raw
# ...                           ...                                        ...
# 1322      Fruits and Fruit Juices                  Apples, raw, without skin
# 1323      Fruits and Fruit Juices                     Apples, raw, with skin
# 1324      Fruits and Fruit Juices  Apples, raw, without skin, cooked, boiled
# 1325      Fruits and Fruit Juices               Apples, raw, gala, with skin
# 1326      Fruits and Fruit Juices               Apples, raw, fuji, with skin
#
#       Protein (kcal/100g)  Carbohydrates (kcal/100g)  Fat (kcal/100g)
# 0                  196.80                     143.56            21.51
# 1                  151.24                     127.68           185.85
# 2                  145.96                     120.64           179.46
# 3                  144.68                     161.48            87.66
# 4                  118.60                     166.84           146.88
# ...                   ...                        ...              ...
# 1322                 1.08                      51.04             1.17
# 1323                 1.04                      55.24             1.53
# 1324                 1.04                      54.56             3.24
# 1325                 1.00                      54.72             1.08
# 1326                 0.80                      60.88             1.62
#
# [1327 rows x 5 columns]

# %%
def rank_food(food):
    prot = food['Protein (kcal/100g)']
    carb = food['Carbohydrates (kcal/100g)']
    fat = food['Fat (kcal/100g)']
    
    if (prot == 0 and carb == 0 and fat == 0):
        return -1
    
    tot = prot + carb + fat
    
    err_prot = abs(tot*0.55/4 - prot) / 100
    err_carb = abs(tot*0.25/4 - carb) / 100
    err_fat = abs(tot*0.20/9 - fat) / 100
    
    avg_err = (err_prot + err_carb + err_fat)/3
    
    return avg_err

# %%
test['rank'] = test.apply(rank_food, axis=1)

# %%
test.sort_values(by="rank")
# Out:
#                              Food Group  \
# 1275  Vegetables and Vegetable Products
# 1220  Vegetables and Vegetable Products
# 1082  Vegetables and Vegetable Products
# 1195  Vegetables and Vegetable Products
# 1260  Vegetables and Vegetable Products
# ...                                 ...
# 1022      Lamb, Veal, and Game Products
# 997                       Pork Products
# 1052                      Pork Products
# 1150                      Beef Products
# 1124                      Pork Products
#
#                                               Food Name  Protein (kcal/100g)  \
# 1275                              Cucumber, peeled, raw                 2.36
# 1220                                   Taro shoots, raw                 3.68
# 1082                                    Watercress, raw                 9.20
# 1195                        Radishes, white icicle, raw                 4.40
# 1260                                        Celery, raw                 2.76
# ...                                                 ...                  ...
# 1022  Lamb, New Zealand, imported, subcutaneous fat,...                15.48
# 997                         Pork, cured, salt pork, raw                20.20
# 1052                          Pork, fresh, backfat, raw                11.68
# 1150     Beef, variety meats and by-products, suet, raw                 6.00
# 1124  Pork, fresh, variety meats and by-products, le...                 7.04
#
#       Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 1275                       8.64             1.44  0.032252
# 1220                       9.28             0.81  0.035700
# 1082                       5.16             0.90  0.039563
# 1195                      10.52             0.90  0.041015
# 1260                      11.88             1.53  0.041922
# ...                         ...              ...       ...
# 1022                       2.20           685.44  2.642530
# 997                        0.00           724.50  2.788970
# 1052                       0.00           798.21  3.101701
# 1150                       0.00           846.00  3.304889
# 1124                       0.00           847.44  3.307692
#
# [1327 rows x 6 columns]

# %%
test.sort_values(by="rank").drop_duplicates("Food Group")
# Out:
#                              Food Group  \
# 1275  Vegetables and Vegetable Products
# 1225            Fruits and Fruit Juices
# 935              Dairy and Egg Products
# 985      Finfish and Shellfish Products
# 922       Lamb, Veal, and Game Products
# 952         Legumes and Legume Products
# 871                       Beef Products
# 1017              Nut and Seed Products
# 889                       Pork Products
# 725                    Poultry Products
# 635         Sausages and Luncheon Meats
# 874             Cereal Grains and Pasta
# 518                    Spices and Herbs
# 1012                     Baked Products
#
#                                               Food Name  Protein (kcal/100g)  \
# 1275                              Cucumber, peeled, raw                 2.36
# 1225                                       Rhubarb, raw                 3.60
# 935                Egg, white, raw, frozen, pasteurized                40.80
# 985                Mollusks, oyster, eastern, wild, raw                22.84
# 922            Lamb, New Zealand, imported, testes, raw                45.60
# 952   Tofu, raw, regular, prepared with calcium sulfate                32.32
# 871   Beef, New Zealand, imported, variety meats and...                59.44
# 1017                            Seeds, lotus seeds, raw                16.52
# 889   Pork, fresh, variety meats and by-products, lu...                56.32
# 725                  Chicken, gizzard, all classes, raw                70.64
# 635                          Turkey sausage, fresh, raw                75.16
# 874                                      Wild rice, raw                58.92
# 518                                Spices, caraway seed                79.08
# 1012  Toaster Pastries, KELLOGG, KELLOGG'S LOW FAT P...                16.80
#
#       Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 1275                       8.64             1.44  0.032252
# 1225                      18.16             1.80  0.061081
# 935                        4.16             0.00  0.123224
# 985                       10.88            15.39  0.127322
# 922                        0.56            21.42  0.199632
# 952                        7.48            43.02  0.214719
# 871                        0.00            17.82  0.232495
# 1017                      69.12             4.77  0.234396
# 889                        0.00            24.48  0.243148
# 725                        0.00            18.54  0.268366
# 635                        1.88            72.72  0.438133
# 874                      299.60             9.72  0.954696
# 518                      199.60           131.31  1.062937
# 1012                     297.60            48.60  1.161861

# %%
# test.groupby(['Food Group'], as_index=False)['rank'].min().merge(test)

# %%
prices = pd.read_csv("../data/raw/ProducerPricesEurope2018.csv", usecols=["Area", "Item", "Value"])
prices.head()
# Out:
#       Area          Item   Value
# 0  Albania        Apples   435.2
# 1  Albania      Apricots   777.8
# 2  Albania        Barley   302.2
# 3  Albania    Beans, dry  2078.7
# 4  Albania  Beans, green   976.7

# %% [markdown]
# **Note: prices in USD/tonne**

# %%
# filtering by considering only the best countries for surplus*population found before
best_countries = ['Spain', 'United Kingdom', 'Italy',
       'France', 'Germany']
prices = prices[prices.Area.isin(best_countries)]

# %%
# the product we are gonna find must be available in all the countries
all_available = prices.groupby("Item").count().Area >= len(best_countries)

# %%
all_available[all_available==True]
# Out:
# Item
# Apples                   True
# Milk, whole fresh cow    True
# Oats                     True
# Potatoes                 True
# Tomatoes                 True
# Wheat                    True
# Name: Area, dtype: bool

# %% [markdown]
# Considering only the total available is too restrictive, so we increase to list dimension - 2

# %%
all_available = prices.groupby("Item").count().Area >= len(best_countries) - 2
all_available[all_available==True]
# Out:
# Item
# Apples                                True
# Apricots                              True
# Asparagus                             True
# Barley                                True
# Beans, dry                            True
# Beans, green                          True
# Cabbages and other brassicas          True
# Carrots and turnips                   True
# Cauliflowers and broccoli             True
# Cherries                              True
# Cucumbers and gherkins                True
# Eggs, hen, in shell                   True
# Hazelnuts, with shell                 True
# Leeks, other alliaceous vegetables    True
# Lettuce and chicory                   True
# Maize                                 True
# Meat live weight, cattle              True
# Meat live weight, chicken             True
# Meat live weight, pig                 True
# Meat live weight, sheep               True
# Meat, cattle                          True
# Meat, chicken                         True
# Meat, horse                           True
# Meat, pig                             True
# Meat, sheep                           True
# Milk, whole fresh cow                 True
# Mushrooms and truffles                True
# Oats                                  True
# Onions, dry                           True
# Peaches and nectarines                True
# Pears                                 True
# Peas, green                           True
# Plums and sloes                       True
# Potatoes                              True
# Rapeseed                              True
# Rice, paddy                           True
# Rye                                   True
# Strawberries                          True
# Sugar beet                            True
# Sunflower seed                        True
# Tobacco, unmanufactured               True
# Tomatoes                              True
# Triticale                             True
# Walnuts, with shell                   True
# Wheat                                 True
# Wool, greasy                          True
# Name: Area, dtype: bool

# %% [markdown]
# The situation improved, we use this as starting point.

# %%
foods = all_available[all_available==True].index.values

# %%
test[test["Food Name"].str.contains('|'.join(foods), case=False)]
# Out:
#                          Food Group  \
# 27      Legumes and Legume Products
# 69                 Poultry Products
# 110                Poultry Products
# 169                Poultry Products
# 260   Lamb, Veal, and Game Products
# ...                             ...
# 1322        Fruits and Fruit Juices
# 1323        Fruits and Fruit Juices
# 1324        Fruits and Fruit Juices
# 1325        Fruits and Fruit Juices
# 1326        Fruits and Fruit Juices
#
#                                               Food Name  Protein (kcal/100g)  \
# 27                Peas, green, split, mature seeds, raw                95.28
# 69    Chicken, broilers or fryers, light meat, meat ...                92.80
# 110   Chicken, broiler or fryers, breast, skinless, ...                90.00
# 169   Chicken, broilers or fryers, wing, meat only, raw                87.88
# 260                               Game meat, horse, raw                85.56
# ...                                                 ...                  ...
# 1322                          Apples, raw, without skin                 1.08
# 1323                             Apples, raw, with skin                 1.04
# 1324          Apples, raw, without skin, cooked, boiled                 1.04
# 1325                       Apples, raw, gala, with skin                 1.00
# 1326                       Apples, raw, fuji, with skin                 0.80
#
#       Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 27                       254.96            10.44  0.935096
# 69                         0.00            14.85  0.323947
# 110                        0.00            23.58  0.341792
# 169                        0.00            31.86  0.360329
# 260                        0.00            41.40  0.382056
# ...                         ...              ...       ...
# 1322                      51.04             1.17  0.179903
# 1323                      55.24             1.53  0.195937
# 1324                      54.56             3.24  0.199551
# 1325                      54.72             1.08  0.193874
# 1326                      60.88             1.62  0.216803
#
# [68 rows x 6 columns]

# %% [markdown]
# 68 rows, but there are multiple matches: look to the elements that don't have a match:

# %%
total_foods = test["Food Name"].unique()
total_foods = [t.lower() for t in total_foods]
foods = [f.lower()for f in foods]

# %%
not_matching = [f for f in foods if not any(f in t for t in total_foods)]

# %%
len(not_matching)
# Out:
# 33

# %%
not_matching[:10]
# Out:
# ['beans, dry',
#  'cabbages and other brassicas',
#  'carrots and turnips',
#  'cauliflowers and broccoli',
#  'cucumbers and gherkins',
#  'eggs, hen, in shell',
#  'hazelnuts, with shell',
#  'leeks, other alliaceous vegetables',
#  'lettuce and chicory',
#  'maize']

# %% [markdown]
# We can try to remove all the commas, () and divide the multiple words, also remove duplicates after that

# %%
foods = [f.replace(",","").replace("(", "").replace(")", "").split() for f in foods]
foods = [l for sublist in foods for l in sublist]
foods = list(set(foods))

# %% [markdown]
# Second step is removing all generated stopwords and add singulars

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
stop_words += ["dry", "weight", "live", "meat", "unmanufactured", "seed", "beans", "sugar", "whole", "peas", "green", "fresh"]
foods = [f for f in foods if f not in stop_words]
lem = WordNetLemmatizer()
singular = [lem.lemmatize(f) for f in foods]
foods += singular
foods = list(set(foods))
foods = [f for f in foods if f not in stop_words]

# %% [markdown]
# New matching check:

# %%
not_matching = [f for f in foods if not any(f in t for t in total_foods)]
len(not_matching)
# Out:
# 30

# %%
test[test["Food Name"].str.contains('|'.join(foods+singular), case=False)].index.size
# Out:
# 208

# %% [markdown]
# We can stop here for the next considerations

# %%
poss_diet = test[test["Food Name"].str.contains('|'.join(foods), case=False)]

# %%
poss_diet["Food Group"].unique()
# Out:
# array(['Legumes and Legume Products', 'Poultry Products',
#        'Lamb, Veal, and Game Products', 'Finfish and Shellfish Products',
#        'Cereal Grains and Pasta', 'Dairy and Egg Products',
#        'Vegetables and Vegetable Products', 'Baked Products',
#        'Nut and Seed Products', 'Fruits and Fruit Juices'], dtype=object)

# %% [markdown]
# We have some groups that are fore sure not possible to help us for building the diet:
# - Baked Products
# - Spices and Herbs
# - Nut and Seed Products
# - Dairy and Egg Products
#
# Also, Finfish and Shellfish Products is not really represented by our prices database.
# So, we drop them

# %%
poss_diet = poss_diet[~poss_diet["Food Group"].isin(["Baked Products","Spices and Herbs", "Nut and Seed Products", "Dairy and Egg Products", "Finfish and Shellfish Products"])].reset_index(drop=True)

# %%
# taking the best 5 from each group
poss_diet_proteins = poss_diet.groupby(["Food Group"]).apply(lambda x: x.sort_values(['Protein (kcal/100g)'], \
                                   ascending=False).reset_index(drop=True).groupby("Food Group").head(5)).reset_index(drop=True)
poss_diet_carbo = poss_diet.groupby(["Food Group"]).apply(lambda x: x.sort_values(['Carbohydrates (kcal/100g)'], \
                                   ascending=False).reset_index(drop=True).groupby("Food Group").head(5)).reset_index(drop=True)
poss_diet_fat = poss_diet.groupby(["Food Group"]).apply(lambda x: x.sort_values(['Fat (kcal/100g)'], \
                                   ascending=False).reset_index(drop=True).groupby("Food Group").head(5)).reset_index(drop=True)

# %%
poss_diet_proteins.sort_values(['rank'])
# Out:
#                            Food Group  \
# 24  Vegetables and Vegetable Products
# 25  Vegetables and Vegetable Products
# 23  Vegetables and Vegetable Products
# 26  Vegetables and Vegetable Products
# 8             Fruits and Fruit Juices
# 6             Fruits and Fruit Juices
# 9             Fruits and Fruit Juices
# 16        Legumes and Legume Products
# 15        Legumes and Legume Products
# 11      Lamb, Veal, and Game Products
# 20                   Poultry Products
# 5             Fruits and Fruit Juices
# 17                   Poultry Products
# 19                   Poultry Products
# 7             Fruits and Fruit Juices
# 21                   Poultry Products
# 22  Vegetables and Vegetable Products
# 10      Lamb, Veal, and Game Products
# 18                   Poultry Products
# 13        Legumes and Legume Products
# 14        Legumes and Legume Products
# 12        Legumes and Legume Products
# 1             Cereal Grains and Pasta
# 2             Cereal Grains and Pasta
# 0             Cereal Grains and Pasta
# 4             Cereal Grains and Pasta
# 3             Cereal Grains and Pasta
#
#                                             Food Name  Protein (kcal/100g)  \
# 24                           Cowpeas, leafy tips, raw                16.40
# 25           Mushrooms, straw, canned, drained solids                15.32
# 23        Balsam-pear (bitter gourd), leafy tips, raw                21.20
# 26                             Mushrooms, oyster, raw                13.24
# 8                                       Apricots, raw                 5.60
# 6    Groundcherries, (cape-gooseberries or poha), raw                 7.60
# 9                                Cherries, sweet, raw                 4.24
# 16                  SILK Banana-Strawberry soy yogurt                 9.40
# 15                         SILK Strawberry soy yogurt                 9.40
# 11                                          Goat, raw                82.40
# 20      Chicken, roasting, light meat, meat only, raw                88.80
# 5                       Sugar-apples, (sweetsop), raw                 8.24
# 17  Chicken, broilers or fryers, light meat, meat ...                92.80
# 19  Chicken, broiler or fryers, breast, skinless, ...                90.00
# 7               Custard-apple, (bullock's-heart), raw                 6.80
# 21  Chicken, broilers or fryers, wing, meat only, raw                87.88
# 22                    Pigeonpeas, immature seeds, raw                28.80
# 10                              Game meat, horse, raw                85.56
# 18       Chicken, stewing, light meat, meat only, raw                92.40
# 13  Cowpeas, common (blackeyes, crowder, southern)...                94.08
# 14          Pigeon peas (red gram), mature seeds, raw                86.80
# 12                Cowpeas, catjang, mature seeds, raw                95.40
# 1                                      Wild rice, raw                58.92
# 2                                Barley, pearled, raw                39.64
# 0                                       Oat bran, raw                69.20
# 4                      Rice, brown, medium-grain, raw                30.00
# 3                        Rice, brown, long-grain, raw                30.16
#
#     Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 24                      19.28             2.25  0.098337
# 25                      18.56             6.12  0.103704
# 23                      13.16             6.21  0.105181
# 26                      24.36             3.69  0.107048
# 8                       44.48             3.51  0.150728
# 6                       44.80             6.30  0.155327
# 9                       64.04             1.80  0.217662
# 16                      68.24            10.62  0.247061
# 15                      72.96            10.62  0.263624
# 11                       0.00            20.79  0.310525
# 20                       0.00            14.67  0.311368
# 5                       94.56             2.61  0.314978
# 17                       0.00            14.85  0.323947
# 19                       0.00            23.58  0.341792
# 7                      100.80             5.40  0.351213
# 21                       0.00            31.86  0.360329
# 22                      95.52            14.76  0.360578
# 10                       0.00            41.40  0.382056
# 18                       0.00            37.89  0.392076
# 13                     240.12            11.34  0.895844
# 14                     251.12            13.41  0.910856
# 12                     238.56            18.63  0.914122
# 1                      299.60             9.72  0.954696
# 2                      310.88            10.44  1.002436
# 0                      264.88            63.27  1.030167
# 4                      304.68            24.12  1.059122
# 3                      305.00            28.80  1.076163

# %%
#sorting the groups by rank
poss_diet_proteins.sort_values(['Protein (kcal/100g)'], ascending=False)
# Out:
#                            Food Group  \
# 12        Legumes and Legume Products
# 13        Legumes and Legume Products
# 17                   Poultry Products
# 18                   Poultry Products
# 19                   Poultry Products
# 20                   Poultry Products
# 21                   Poultry Products
# 14        Legumes and Legume Products
# 10      Lamb, Veal, and Game Products
# 11      Lamb, Veal, and Game Products
# 0             Cereal Grains and Pasta
# 1             Cereal Grains and Pasta
# 2             Cereal Grains and Pasta
# 3             Cereal Grains and Pasta
# 4             Cereal Grains and Pasta
# 22  Vegetables and Vegetable Products
# 23  Vegetables and Vegetable Products
# 24  Vegetables and Vegetable Products
# 25  Vegetables and Vegetable Products
# 26  Vegetables and Vegetable Products
# 15        Legumes and Legume Products
# 16        Legumes and Legume Products
# 5             Fruits and Fruit Juices
# 6             Fruits and Fruit Juices
# 7             Fruits and Fruit Juices
# 8             Fruits and Fruit Juices
# 9             Fruits and Fruit Juices
#
#                                             Food Name  Protein (kcal/100g)  \
# 12                Cowpeas, catjang, mature seeds, raw                95.40
# 13  Cowpeas, common (blackeyes, crowder, southern)...                94.08
# 17  Chicken, broilers or fryers, light meat, meat ...                92.80
# 18       Chicken, stewing, light meat, meat only, raw                92.40
# 19  Chicken, broiler or fryers, breast, skinless, ...                90.00
# 20      Chicken, roasting, light meat, meat only, raw                88.80
# 21  Chicken, broilers or fryers, wing, meat only, raw                87.88
# 14          Pigeon peas (red gram), mature seeds, raw                86.80
# 10                              Game meat, horse, raw                85.56
# 11                                          Goat, raw                82.40
# 0                                       Oat bran, raw                69.20
# 1                                      Wild rice, raw                58.92
# 2                                Barley, pearled, raw                39.64
# 3                        Rice, brown, long-grain, raw                30.16
# 4                      Rice, brown, medium-grain, raw                30.00
# 22                    Pigeonpeas, immature seeds, raw                28.80
# 23        Balsam-pear (bitter gourd), leafy tips, raw                21.20
# 24                           Cowpeas, leafy tips, raw                16.40
# 25           Mushrooms, straw, canned, drained solids                15.32
# 26                             Mushrooms, oyster, raw                13.24
# 15                         SILK Strawberry soy yogurt                 9.40
# 16                  SILK Banana-Strawberry soy yogurt                 9.40
# 5                       Sugar-apples, (sweetsop), raw                 8.24
# 6    Groundcherries, (cape-gooseberries or poha), raw                 7.60
# 7               Custard-apple, (bullock's-heart), raw                 6.80
# 8                                       Apricots, raw                 5.60
# 9                                Cherries, sweet, raw                 4.24
#
#     Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 12                     238.56            18.63  0.914122
# 13                     240.12            11.34  0.895844
# 17                       0.00            14.85  0.323947
# 18                       0.00            37.89  0.392076
# 19                       0.00            23.58  0.341792
# 20                       0.00            14.67  0.311368
# 21                       0.00            31.86  0.360329
# 14                     251.12            13.41  0.910856
# 10                       0.00            41.40  0.382056
# 11                       0.00            20.79  0.310525
# 0                      264.88            63.27  1.030167
# 1                      299.60             9.72  0.954696
# 2                      310.88            10.44  1.002436
# 3                      305.00            28.80  1.076163
# 4                      304.68            24.12  1.059122
# 22                      95.52            14.76  0.360578
# 23                      13.16             6.21  0.105181
# 24                      19.28             2.25  0.098337
# 25                      18.56             6.12  0.103704
# 26                      24.36             3.69  0.107048
# 15                      72.96            10.62  0.263624
# 16                      68.24            10.62  0.247061
# 5                       94.56             2.61  0.314978
# 6                       44.80             6.30  0.155327
# 7                      100.80             5.40  0.351213
# 8                       44.48             3.51  0.150728
# 9                       64.04             1.80  0.217662

# %%
#sorting the groups by rank
poss_diet_carbo.sort_values(['Carbohydrates (kcal/100g)'], \
                                   ascending=False)
# Out:
#                            Food Group  \
# 0             Cereal Grains and Pasta
# 1             Cereal Grains and Pasta
# 2             Cereal Grains and Pasta
# 3             Cereal Grains and Pasta
# 4             Cereal Grains and Pasta
# 12        Legumes and Legume Products
# 13        Legumes and Legume Products
# 14        Legumes and Legume Products
# 5             Fruits and Fruit Juices
# 6             Fruits and Fruit Juices
# 22  Vegetables and Vegetable Products
# 7             Fruits and Fruit Juices
# 8             Fruits and Fruit Juices
# 9             Fruits and Fruit Juices
# 23  Vegetables and Vegetable Products
# 24  Vegetables and Vegetable Products
# 25  Vegetables and Vegetable Products
# 15        Legumes and Legume Products
# 26  Vegetables and Vegetable Products
# 16        Legumes and Legume Products
# 17                   Poultry Products
# 18                   Poultry Products
# 19                   Poultry Products
# 20                   Poultry Products
# 21                   Poultry Products
# 11      Lamb, Veal, and Game Products
# 10      Lamb, Veal, and Game Products
#
#                                             Food Name  Protein (kcal/100g)  \
# 0     Rice, white, long-grain, regular, raw, enriched                28.52
# 1   Rice, white, long-grain, regular, raw, unenriched                28.52
# 2            Rice, white, medium-grain, raw, enriched                26.44
# 3          Rice, white, medium-grain, raw, unenriched                26.44
# 4           Rice, white, short-grain, raw, unenriched                26.00
# 12          Pigeon peas (red gram), mature seeds, raw                86.80
# 13  Cowpeas, common (blackeyes, crowder, southern)...                94.08
# 14                Cowpeas, catjang, mature seeds, raw                95.40
# 5             Strawberries, frozen, sweetened, sliced                 2.12
# 6               Custard-apple, (bullock's-heart), raw                 6.80
# 22                    Pigeonpeas, immature seeds, raw                28.80
# 7                       Sugar-apples, (sweetsop), raw                 8.24
# 8   Strawberries, canned, heavy syrup pack, solids...                 2.24
# 9              Strawberries, frozen, sweetened, whole                 2.08
# 23                      Sweet potato, raw, unprepared                 6.28
# 24           Cowpeas (blackeyes), immature seeds, raw                11.80
# 25                   Salsify, (vegetable oyster), raw                13.20
# 15                         SILK Strawberry soy yogurt                 9.40
# 26              Potatoes, russet, flesh and skin, raw                 8.56
# 16                  SILK Banana-Strawberry soy yogurt                 9.40
# 17                     Chicken, stewing, giblets, raw                71.56
# 18          Chicken, broilers or fryers, giblets, raw                71.52
# 19                      Chicken, capons, giblets, raw                73.12
# 20                    Chicken, roasting, giblets, raw                72.56
# 21         Chicken, skin (drumsticks and thighs), raw                38.32
# 11                                          Goat, raw                82.40
# 10                              Game meat, horse, raw                85.56
#
#     Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 0                      319.80             5.94  1.065940
# 1                      319.80             5.94  1.065940
# 2                      317.36             5.22  1.065442
# 3                      317.36             5.22  1.065442
# 4                      316.60             4.68  1.065611
# 12                     251.12            13.41  0.910856
# 13                     240.12            11.34  0.895844
# 14                     238.56            18.63  0.914122
# 5                      103.68             1.17  0.369300
# 6                      100.80             5.40  0.351213
# 22                      95.52            14.76  0.360578
# 7                       94.56             2.61  0.314978
# 8                       94.12             2.34  0.331431
# 9                       84.00             1.26  0.297171
# 23                      80.48             0.45  0.274096
# 24                      75.32             3.15  0.238114
# 25                      74.40             1.80  0.233022
# 15                      72.96            10.62  0.263624
# 26                      72.28             0.72  0.236431
# 16                      68.24            10.62  0.247061
# 17                       8.52            82.89  0.433619
# 18                       7.20            40.23  0.309951
# 19                       5.68            46.62  0.339555
# 20                       4.56            45.36  0.338174
# 21                       3.16           398.07  1.449107
# 11                       0.00            20.79  0.310525
# 10                       0.00            41.40  0.382056

# %%
#sorting the groups by rank
poss_diet_fat.sort_values(['Fat (kcal/100g)'], ascending=False)
# Out:
#                            Food Group  \
# 17                   Poultry Products
# 18                   Poultry Products
# 19                   Poultry Products
# 20                   Poultry Products
# 21                   Poultry Products
# 0             Cereal Grains and Pasta
# 10      Lamb, Veal, and Game Products
# 1             Cereal Grains and Pasta
# 2             Cereal Grains and Pasta
# 11      Lamb, Veal, and Game Products
# 12        Legumes and Legume Products
# 22  Vegetables and Vegetable Products
# 13        Legumes and Legume Products
# 5             Fruits and Fruit Juices
# 14        Legumes and Legume Products
# 15        Legumes and Legume Products
# 16        Legumes and Legume Products
# 3             Cereal Grains and Pasta
# 4             Cereal Grains and Pasta
# 23  Vegetables and Vegetable Products
# 6             Fruits and Fruit Juices
# 24  Vegetables and Vegetable Products
# 25  Vegetables and Vegetable Products
# 8             Fruits and Fruit Juices
# 7             Fruits and Fruit Juices
# 26  Vegetables and Vegetable Products
# 9             Fruits and Fruit Juices
#
#                                             Food Name  Protein (kcal/100g)  \
# 17    Chicken, broilers or fryers, separable fat, raw                14.92
# 18         Chicken, skin (drumsticks and thighs), raw                38.32
# 19  Chicken, skin (drumsticks and thighs), with ad...                44.44
# 20        Chicken, broilers or fryers, skin only, raw                53.32
# 21  Chicken, broilers or fryers, back, meat and sk...                56.20
# 0                                       Oat bran, raw                69.20
# 10                              Game meat, horse, raw                85.56
# 1                        Rice, brown, long-grain, raw                30.16
# 2                      Rice, brown, medium-grain, raw                30.00
# 11                                          Goat, raw                82.40
# 12                Cowpeas, catjang, mature seeds, raw                95.40
# 22                    Pigeonpeas, immature seeds, raw                28.80
# 13          Pigeon peas (red gram), mature seeds, raw                86.80
# 5                          Carissa, (natal-plum), raw                 2.00
# 14  Cowpeas, common (blackeyes, crowder, southern)...                94.08
# 15                         SILK Strawberry soy yogurt                 9.40
# 16                  SILK Banana-Strawberry soy yogurt                 9.40
# 3                                Barley, pearled, raw                39.64
# 4                                      Wild rice, raw                58.92
# 23                             Broccoli, chinese, raw                 4.80
# 6    Groundcherries, (cape-gooseberries or poha), raw                 7.60
# 24        Balsam-pear (bitter gourd), leafy tips, raw                21.20
# 25           Mushrooms, straw, canned, drained solids                15.32
# 8                             Guavas, strawberry, raw                 2.32
# 7               Custard-apple, (bullock's-heart), raw                 6.80
# 26                              Mushrooms, morel, raw                12.48
# 9                                  Prickly pears, raw                 2.92
#
#     Carbohydrates (kcal/100g)  Fat (kcal/100g)      rank
# 17                       0.00           611.55  2.360008
# 18                       3.16           398.07  1.449107
# 19                       0.04           341.10  1.217225
# 20                       0.00           291.15  1.036600
# 21                       0.00           258.66  0.947495
# 0                      264.88            63.27  1.030167
# 10                       0.00            41.40  0.382056
# 1                      305.00            28.80  1.076163
# 2                      304.68            24.12  1.059122
# 11                       0.00            20.79  0.310525
# 12                     238.56            18.63  0.914122
# 22                      95.52            14.76  0.360578
# 13                     251.12            13.41  0.910856
# 5                       54.52            11.70  0.226068
# 14                     240.12            11.34  0.895844
# 15                      72.96            10.62  0.263624
# 16                      68.24            10.62  0.247061
# 3                      310.88            10.44  1.002436
# 4                      299.60             9.72  0.954696
# 23                      18.68             6.84  0.078607
# 6                       44.80             6.30  0.155327
# 24                      13.16             6.21  0.105181
# 25                      18.56             6.12  0.103704
# 8                       69.44             5.40  0.255308
# 7                      100.80             5.40  0.351213
# 26                      20.40             5.13  0.098544
# 9                       38.28             4.59  0.141222

# %% [markdown]
# As such, and taking into account the necessity that each person, in their diet, should have their calories coming (**REFERENCE**):
# * 55% from proteins
# * 25% from carbohydrates
# * 20% from fats.
# We have values of **kcal/100g**. What we can do is try to build a diet with the data gathered so far, that represent almost all the Food Group categories we have, but having also data for prices in our interested countries.
# In order to do so, we can consider a diet of **1000 kcal**, then we will be able to scale the grams of product based on this.

# %%
prices[prices.Item=="Rice, paddy"]
# Out:
#         Area         Item  Value
# 521   France  Rice, paddy  372.0
# 779    Italy  Rice, paddy  403.7
# 1527   Spain  Rice, paddy  344.6
